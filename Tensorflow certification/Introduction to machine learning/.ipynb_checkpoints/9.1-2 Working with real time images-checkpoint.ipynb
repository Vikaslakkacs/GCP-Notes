# %% [markdown]
# ### we will work with real time images here bu ysing Image data geenrator.

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip \
    -O /tmp/horse-or-human.zip
# Out:
# --2020-05-12 07:01:18--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.195.128, 2607:f8b0:400e:c09::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘/tmp/horse-or-human.zip’
#
# /tmp/horse-or-human 100%[===================>] 142.65M  86.3MB/s    in 1.7s
#
# 2020-05-12 07:01:20 (86.3 MB/s) - ‘/tmp/horse-or-human.zip’ saved [149574867/149574867]

# %%
import os
import zipfile

# %%
batch_file='/tmp/horse-or-human.zip'
zip_file=zipfile.ZipFile(batch_file,'r')
zip_file.extractall('/tmp/horse-or-human')
zip_file.close()

# %%
horses_list=os.listdir('/tmp/horse-or-human/horses')

# %%
horses_list[:10]
# Out:
# ['horse23-7.png',
#  'horse29-9.png',
#  'horse13-3.png',
#  'horse28-9.png',
#  'horse09-0.png',
#  'horse50-3.png',
#  'horse20-3.png',
#  'horse03-0.png',
#  'horse20-6.png',
#  'horse33-3.png']

# %%
sample_horse=os.path.join('/tmp/horse-or-human/horses',horses_list[23])

# %%
sample_horse
# Out:
# '/tmp/horse-or-human/horses/horse15-5.png'

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(plt.imread(sample_horse))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPooling2D
import numpy as np
