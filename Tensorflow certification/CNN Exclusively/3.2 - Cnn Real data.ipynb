# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip \
    -O /tmp/horse-or-human.zip
# Out:
# --2020-06-04 09:36:44--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.71.128, 2a00:1450:400c:c0c::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.71.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘/tmp/horse-or-human.zip’
#
# /tmp/horse-or-human 100%[===================>] 142.65M  88.9MB/s    in 1.6s
#
# 2020-06-04 09:36:46 (88.9 MB/s) - ‘/tmp/horse-or-human.zip’ saved [149574867/149574867]

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import zipfile

# %%
zip_file=zipfile.ZipFile('/tmp/horse-or-human.zip','r')
zip_file.extractall('/tmp/horses_humans')
zip_file.close()

# %%
os.listdir('/tmp/horses_humans')
# Out:
# ['humans', 'horses']

# %%
train_path=os.path.join('/tmp/horses_humans')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen=ImageDataGenerator(rescale=1/255)

# %%
train_gen=image_gen.flow_from_directory(train_path,target_size=(300,300),class_mode='binary',shuffle=True)
# Out:
# Found 1027 images belonging to 2 classes.

# %%
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPooling2D,Dropout
from tensorflow.keras.optimizers import Adam

# %%
model=keras.Sequential()
model.add(Conv2D(filters=32,kernel_size=(2,2),strides=(1,1),input_shape=(300,300,3),padding='SAME',activation=tf.nn.relu))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=64,kernel_size=(2,2),strides=(3,3),padding='SAME',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=128,kernel_size=(2,2),strides=(1,1),padding='SAME',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

adam=Adam(learning_rate=0.001)
model.compile(optimizer=adam,loss=keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_103 (Conv2D)          (None, 300, 300, 32)      416
# _________________________________________________________________
# max_pooling2d_99 (MaxPooling (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_104 (Conv2D)          (None, 50, 50, 64)        8256
# _________________________________________________________________
# max_pooling2d_100 (MaxPoolin (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_105 (Conv2D)          (None, 25, 25, 128)       32896
# _________________________________________________________________
# max_pooling2d_101 (MaxPoolin (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 12, 12, 128)       0
# ...

# %%
model.fit(train_gen,epochs=20,shuffle=True)
# Out:
# Epoch 1/20
# 33/33 [==============================] - 8s 228ms/step - loss: 0.6456 - accuracy: 0.6485
# Epoch 2/20
# 33/33 [==============================] - 8s 230ms/step - loss: 0.5275 - accuracy: 0.9377
# Epoch 3/20
# 33/33 [==============================] - 8s 229ms/step - loss: 0.5124 - accuracy: 0.9747
# Epoch 4/20
# 33/33 [==============================] - 8s 229ms/step - loss: 0.5042 - accuracy: 0.9873
# Epoch 5/20
# 33/33 [==============================] - 8s 230ms/step - loss: 0.5023 - accuracy: 0.9903
# Epoch 6/20
# 33/33 [==============================] - 8s 231ms/step - loss: 0.5000 - accuracy: 0.9981
# Epoch 7/20
# 33/33 [==============================] - 8s 232ms/step - loss: 0.4983 - accuracy: 1.0000
# Epoch 8/20
# 33/33 [==============================] - 8s 233ms/step - loss: 0.4983 - accuracy: 1.0000
# Epoch 9/20
# 33/33 [==============================] - 8s 232ms/step - loss: 0.4983 - accuracy: 1.0000
# Epoch 10/20
# ...

# %%
model=keras.Sequential()
model.add(Conv2D(filters=32,kernel_size=(2,2),strides=(2,2),padding='SAME',input_shape=(300,300,3),activation=tf.nn.relu))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=64,kernel_size=(3,3),strides=(2,2),activation=tf.nn.relu))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=128,kernel_size=(2,2),strides=(2,2),padding='SAME',activation=tf.nn.relu))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())
model.add(Dense(units=128,activation=tf.nn.relu))
model.add(Dense(units=1,activation=tf.nn.sigmoid))
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),loss=keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_97 (Conv2D)           (None, 150, 150, 32)      416
# _________________________________________________________________
# max_pooling2d_93 (MaxPooling (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 37, 37, 64)        18496
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling (None, 18, 18, 64)        0
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 9, 9, 128)         32896
# _________________________________________________________________
# max_pooling2d_95 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 4, 4, 128)         0
# ...

# %%
model.fit(train_gen,epochs=20,shuffle=True)
# Out:
# Epoch 1/20
# 33/33 [==============================] - 7s 217ms/step - loss: 0.6947 - accuracy: 0.4810
# Epoch 2/20
# 33/33 [==============================] - 7s 215ms/step - loss: 0.5886 - accuracy: 0.8247
# Epoch 3/20
# 33/33 [==============================] - 7s 216ms/step - loss: 0.5242 - accuracy: 0.9494
# Epoch 4/20
# 17/33 [==============>...............] - ETA: 3s - loss: 0.5384 - accuracy: 0.9173
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-d167455677a8> in <module>()
# ----> 1 model.fit(train_gen,epochs=20,shuffle=True)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
# ...
