# %%
# !wget --no-check-certificate \
  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
  -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2020-06-04 16:13:26--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.12.128, 2607:f8b0:400c:c07::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.12.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   187MB/s    in 0.3s
#
# 2020-06-04 16:13:27 (187 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
zip_file=zipfile.ZipFile('/tmp/cats_and_dogs_filtered.zip','r')

# %%
zip_file.extractall('/tmp/cats_dogs')
zip_file.close()

# %%
path=os.path.join('/tmp/cats_dogs/cats_and_dogs_filtered')

# %%
path
# Out:
# '/tmp/cats_dogs/cats_and_dogs_filtered'

# %%
os.listdir(path)
# Out:
# ['train', 'vectorize.py', 'validation']

# %%
train_path=os.path.join(path,'train')
test_path=os.path.join(path,'validation')

# %%
train_path
# Out:
# '/tmp/cats_dogs/cats_and_dogs_filtered/train'

# %%
os.listdir(train_path)
# Out:
# ['dogs', 'cats']

# %%
sample_path=os.path.join(train_path,'cats')
sample_1=os.path.join(train_path,'dogs')

# %%
sample_path=os.path.join(sample_path,'cat.472.jpg')

# %%
#os.listdir(sample_1)
sample_2=os.listdir(sample_1)
len(sample_2)
# Out:
# 1000

# %%
sample_path
# Out:
# '/tmp/cats_dogs/cats_and_dogs_filtered/train/cats/cat.472.jpg'

# %%
plt.imshow(plt.imread(sample_path))

# %%
#image Data Generator
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img_gen=ImageDataGenerator(rescale=1/255)

# %%
train_gen=img_gen.flow_from_directory(train_path,target_size=(200,200),
                                      batch_size=20,
                                      class_mode='binary',
                                      shuffle=True)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
test_gen=img_gen.flow_from_directory(test_path,target_size=(200,200),
                                     batch_size=20,
                                     class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPooling2D,Dropout

# %%
model=keras.Sequential()
model.add(Conv2D(filters=32,kernel_size=(2,2),strides=(1,1),input_shape=(200,200,3),padding='SAME',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=64,kernel_size=(2,2),strides=(1,1),padding='SAME',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate=0.3))
model.add(Conv2D(filters=128,kernel_size=(2,2),strides=(1,1),activation='relu',padding='SAME'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(optimizer=keras.optimizers.RMSprop(learning_rate=0.0001),loss=keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_32 (Conv2D)           (None, 200, 200, 32)      416
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 100, 100, 64)      8256
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 50, 50, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 50, 50, 128)       32896
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 25, 25, 128)       0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 80000)             0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               10240128
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 10,281,825
# Trainable params: 10,281,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_gen,epochs=50,validation_data=(test_gen),steps_per_epoch=100,validation_steps=50)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.6956 - accuracy: 0.4985 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 2/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 4/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6931 - accuracy: 0.5005 - val_loss: 0.6963 - val_accuracy: 0.5010
# Epoch 6/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6925 - accuracy: 0.5015 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 7/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.6886 - accuracy: 0.5185 - val_loss: 0.6863 - val_accuracy: 0.5110
# Epoch 8/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6839 - accuracy: 0.5445 - val_loss: 0.6886 - val_accuracy: 0.6100
# Epoch 9/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6753 - accuracy: 0.5675 - val_loss: 0.6795 - val_accuracy: 0.6160
# Epoch 10/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6694 - accuracy: 0.5865 - val_loss: 0.6727 - val_accuracy: 0.6260
# Epoch 11/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6657 - accuracy: 0.5950 - val_loss: 0.6874 - val_accuracy: 0.6430
# Epoch 12/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6632 - accuracy: 0.5950 - val_loss: 0.6608 - val_accuracy: 0.6120
# Epoch 13/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6589 - accuracy: 0.6125 - val_loss: 0.6575 - val_accuracy: 0.6200
# Epoch 14/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6557 - accuracy: 0.6185 - val_loss: 0.6874 - val_accuracy: 0.6430
# Epoch 15/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6514 - accuracy: 0.6425 - val_loss: 0.6527 - val_accuracy: 0.6530
# Epoch 16/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6476 - accuracy: 0.6440 - val_loss: 0.6547 - val_accuracy: 0.6590
# Epoch 17/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6421 - accuracy: 0.6615 - val_loss: 0.6505 - val_accuracy: 0.6540
# Epoch 18/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.6385 - accuracy: 0.6775 - val_loss: 0.6512 - val_accuracy: 0.6630
# Epoch 19/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6373 - accuracy: 0.6855 - val_loss: 0.6478 - val_accuracy: 0.6680
# Epoch 20/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6328 - accuracy: 0.6965 - val_loss: 0.6441 - val_accuracy: 0.6560
# Epoch 21/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6295 - accuracy: 0.7010 - val_loss: 0.6568 - val_accuracy: 0.6780
# Epoch 22/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6269 - accuracy: 0.7165 - val_loss: 0.6417 - val_accuracy: 0.6470
# Epoch 23/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6241 - accuracy: 0.7160 - val_loss: 0.6398 - val_accuracy: 0.6730
# Epoch 24/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6225 - accuracy: 0.7250 - val_loss: 0.6399 - val_accuracy: 0.6410
# Epoch 25/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6223 - accuracy: 0.7200 - val_loss: 0.6379 - val_accuracy: 0.6680
# Epoch 26/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6178 - accuracy: 0.7350 - val_loss: 0.6411 - val_accuracy: 0.6940
# Epoch 27/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.6156 - accuracy: 0.7395 - val_loss: 0.6383 - val_accuracy: 0.6730
# Epoch 28/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6144 - accuracy: 0.7515 - val_loss: 0.6374 - val_accuracy: 0.6720
# Epoch 29/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.6111 - accuracy: 0.7505 - val_loss: 0.6399 - val_accuracy: 0.6810
# Epoch 30/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.6094 - accuracy: 0.7545 - val_loss: 0.6345 - val_accuracy: 0.6850
# Epoch 31/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.6099 - accuracy: 0.7505 - val_loss: 0.6355 - val_accuracy: 0.6760
# Epoch 32/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.6084 - accuracy: 0.7610 - val_loss: 0.6334 - val_accuracy: 0.6860
# Epoch 33/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.6056 - accuracy: 0.7680 - val_loss: 0.6427 - val_accuracy: 0.7120
# Epoch 34/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6028 - accuracy: 0.7705 - val_loss: 0.6360 - val_accuracy: 0.6840
# Epoch 35/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6023 - accuracy: 0.7780 - val_loss: 0.6351 - val_accuracy: 0.6960
# Epoch 36/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6009 - accuracy: 0.7830 - val_loss: 0.6333 - val_accuracy: 0.6940
# Epoch 37/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.5984 - accuracy: 0.7885 - val_loss: 0.6383 - val_accuracy: 0.6860
# Epoch 38/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.5984 - accuracy: 0.7850 - val_loss: 0.6342 - val_accuracy: 0.6930
# Epoch 39/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.5967 - accuracy: 0.7880 - val_loss: 0.6414 - val_accuracy: 0.7060
# Epoch 40/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5929 - accuracy: 0.8030 - val_loss: 0.6339 - val_accuracy: 0.6990
# Epoch 41/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5939 - accuracy: 0.8035 - val_loss: 0.6378 - val_accuracy: 0.7110
# Epoch 42/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.5891 - accuracy: 0.8150 - val_loss: 0.6297 - val_accuracy: 0.7080
# Epoch 43/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5894 - accuracy: 0.8085 - val_loss: 0.6476 - val_accuracy: 0.6880
# Epoch 44/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.5891 - accuracy: 0.8095 - val_loss: 0.6366 - val_accuracy: 0.7040
# Epoch 45/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5867 - accuracy: 0.8170 - val_loss: 0.6365 - val_accuracy: 0.6990
# Epoch 46/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5831 - accuracy: 0.8295 - val_loss: 0.6308 - val_accuracy: 0.7030
# Epoch 47/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5818 - accuracy: 0.8235 - val_loss: 0.6380 - val_accuracy: 0.7040
# Epoch 48/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5827 - accuracy: 0.8230 - val_loss: 0.6375 - val_accuracy: 0.7090
# Epoch 49/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.5796 - accuracy: 0.8325 - val_loss: 0.6332 - val_accuracy: 0.7140
# Epoch 50/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5775 - accuracy: 0.8375 - val_loss: 0.6309 - val_accuracy: 0.7040

# %%
metrics=model.history.history
loss=metrics['loss']
val_loss=metrics['val_loss']
acc=metrics['accuracy']
val_acc=metrics['val_accuracy']

# %%
plt.plot(loss)
plt.plot(val_loss)

# %%
plt.plot(acc)
plt.plot(val_acc)

# %%
#### Lets see some intermediate results using model
layers=model.layers

# %%
### Lets take the output of every layer and store it in list
### Exclusing the first layer because we will send the first layer as input. That comes under input
output_layer=[layer.output for layer in layers[1:]]

# %%
output_layer
# Out:
# [<tf.Tensor 'max_pooling2d_32/Identity:0' shape=(None, 100, 100, 32) dtype=float32>,
#  <tf.Tensor 'conv2d_33/Identity:0' shape=(None, 100, 100, 64) dtype=float32>,
#  <tf.Tensor 'max_pooling2d_33/Identity:0' shape=(None, 50, 50, 64) dtype=float32>,
#  <tf.Tensor 'dropout/Identity:0' shape=(None, 50, 50, 64) dtype=float32>,
#  <tf.Tensor 'conv2d_34/Identity:0' shape=(None, 50, 50, 128) dtype=float32>,
#  <tf.Tensor 'max_pooling2d_34/Identity:0' shape=(None, 25, 25, 128) dtype=float32>,
#  <tf.Tensor 'flatten_11/Identity:0' shape=(None, 80000) dtype=float32>,
#  <tf.Tensor 'dense_22/Identity:0' shape=(None, 128) dtype=float32>,
#  <tf.Tensor 'dense_23/Identity:0' shape=(None, 1) dtype=float32>]

# %%
## Now we will define what should be the model like what are the input parameters and what should be the output parameter
## This will create a class
visualize_layers=keras.models.Model(inputs=model.input,outputs=output_layer)

# %%
visualize_layers

# %%
sample_image=plt.imread(sample_path)

# %%
sample_image.shape
# Out:
# (358, 300, 3)

# %%
plt.imshow(sample_image)

# %%
## Now let visualise the various features from different layers of the model
import cv2
sample_image=cv2.imread(sample_path)

# %%
sample_image=cv2.resize(sample_image,(200,200))

# %%
sample_image.shape
# Out:
# (200, 200, 3)

# %%
sample_image=sample_image.reshape((-1,200,200,3))

# %%
### NOw lets generate feature maps
feature_maps=visualize_layers.predict(sample_image)

# %%
### Each value in the list corresponds each layer
len(feature_maps)
# Out:
# 9

# %%
## If we see each layer it has images equal to num of dimensions
feature_maps[1].shape
# Out:
# (1, 100, 100, 64)

# %%
#lets plot one
sample_output=feature_maps[1].reshape(100,100,64)

# %%
sample_output.shape
# Out:
# (100, 100, 64)

# %%
## Lets take one image from these 64 images(features)
feature_image=sample_output[:,:,55]

# %%
plt.imshow(feature_image)

# %%
### Now we will take 5th layer and some feature
feature_image=feature_maps[4].reshape((50,50,128))

# %%
feature_output=feature_image[:,:,123]

# %%
plt.imshow(feature_output)
